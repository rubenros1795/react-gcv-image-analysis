# %%
from functions import *
from random import sample
from htmldate import find_date
from concurrent.futures import ThreadPoolExecutor
from bs4 import BeautifulSoup
import json
from langid.langid import LanguageIdentifier, model
from collections import Counter
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.ticker as ticker
import matplotlib.cm as cm
import matplotlib as mpl

# %matplotlib inline

# %%
base_path = "/media/ruben/Data Drive/react-data/protest/carlo"

# %%
# Get Publication Dates

dates_ref = dict()

for photo in [d for d in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, d))]:
    photo_folder = os.path.join(base_path, photo)
    with open(os.path.join(photo_folder,"dates.txt"),'r') as f:
        x = f.readlines()
    dates_ref.update({d.split('|')[0]:d.split('|')[-1].replace('\n','') for d in x if d.split('|')[-1].replace('\n','') != "na" and "ERROR" not in d.split('|')[-1].replace('\n','')})

# Get URL-ID from entity files
ids_ = dict()

for photo in [d for d in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, d))]:
    photo_folder = os.path.join(base_path, photo)
    
    folders = [fol for fol in os.listdir(photo_folder) if os.path.isdir(os.path.join(photo_folder,fol)) and "source" not in fol and "context" not in fol]
    
    for f in folders:
        fn = os.path.join(photo_folder, f, "txt","parsed_text.json")

        with open(fn) as fp:
            file = json.load(fp)
        
        for id_ in file.keys():
            
            identif = id_.split("html_")[0].split('html/')[-1][:-1]
            url = id_.split("html_")[1]
            ids_.update({url:identif})

# %%
d_ = []
for photo in [d for d in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, d))]:
    photo_folder = os.path.join(base_path, photo)
    
    with open(os.path.join(photo_folder,'languages-'+photo+".json"),'r') as f:
        lang = json.load(f)
    
    for photo,items1 in lang.items():
        
        for identifier,langlist in items1.items():
            
            identifier1 = identifier.split('/html/')[-1][:-5]
            language = langlist[0]
            
            if identifier1 in ids_.keys():
                url = ids_[identifier1]
                
                if url in dates_ref.keys():
                    d_.append([dates_ref[url][0:4],language])

# %%
items1
# Out:
# {'http://omonoianews.com/uncategorized/2015/07/karlo-tzouliani-grafontas-me-ema-ti-sigchroni-istoria/attachment/carlo-giuliani/': ['en',
#   1.0,
#   'text'],
#  'http://www.agoravox.it/Pistole-e-ordine-pubblico-cose-da.html': ['it',
#   0.9999986806850218,
#   'url'],
#  'http://vascote.tec.pupso.pw/kACKeactz4V37K7FDnwUClB/': ['da',
#   0.2446427490291237,
#   'text'],
#  'http://www.agoravox.it/In-ricordo-di-Carlo-Giuliani-che.html': ['it',
#   0.9999999997019122,
#   'url'],
#  'https://omonoianews.com/uncategorized/2015/07/karlo-tzouliani-grafontas-me-ema-ti-sigchroni-istoria/': ['en',
#   1.0,
#   'text'],
#  'https://omonoianews.com/uncategorized/2015/07/karlo-tzouliani-grafontas-me-ema-ti-sigchroni-istoria/attachment/carlo-giuliani/': ['en',
#   1.0,
#   'text'],
#  'https://omonoianews.com/uncategorized/2015/07/karlo-tzouliani-grafontas-me-ema-ti-sigchroni-istoria/attachment/carlo-giuliani-1/': ['en',
#   1.0,
#   'text'],
# ...

# %%
d_ = pd.DataFrame(d_,columns=['year','lan'])
d_['count'] = 1
d_['year'] = d_['year'].astype(int)
d_ = d_[(d_['year'] > 2003) & (d_['year'] < 2020)]

lan_counts = dict()

for l in list(set(d_['lan'])):
    lan_counts.update({l:sum(d_[d_['lan'] == l]['count'])})

d_ = d_[d_['lan'].isin([k for k,v in lan_counts.items() if v > 10])]

# %%
d_ = d_.groupby(['lan','year']).sum().reset_index()
d_ = d_.pivot(index='year',columns='lan',values='count').reset_index()
d_ = d_.fillna(0)

# %%
p = d_.plot(x="year", y = list(d_.columns)[1:], kind="area", colormap = "tab20b", figsize=(20,10)).legend(bbox_to_anchor=(1, 1))
plt.title('Frequency of Webpage Languages (with total n > 10) in period 2003-2019')
fig = p.get_figure()
fig.savefig('language-freq-diachron.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-4b4436c1d445> in <module>
# ----> 1 p = d_.plot(x="year", y = list(d_.columns)[1:], kind="area", colormap = "tab20b", figsize=(20,10)).legend(bbox_to_anchor=(1, 1))
#       2 plt.title('Frequency of Webpage Languages (with total n > 10) in period 2003-2019')
#       3 fig = p.get_figure()
#       4 fig.savefig('language-freq-diachron.png')
#
# ~/.local/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~/.local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ...

# %%
suitable = [c for c in list(d_.columns)[1:] if sum(d_[c]) > 5]

# %%
d_
# Out:
# lan  year    an    ar   az   bg   bn   ca   cs   da    de  ...   sk   sq   sr  \
# 0    1995   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN  NaN
# 1    1998   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN  NaN
# 2    2000   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN  NaN
# 3    2001   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN  NaN
# 4    2002   NaN   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN  NaN
# 5    2003   4.0   NaN  NaN  NaN  NaN  NaN  NaN  2.0   2.0  ...  1.0  NaN  NaN
# 6    2004   2.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN  NaN
# 7    2005   1.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN  NaN
# 8    2006   NaN   NaN  NaN  NaN  NaN  NaN  NaN  1.0   NaN  ...  NaN  NaN  NaN
# 9    2007   1.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN  NaN
# 10   2008   1.0   NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN  ...  NaN  NaN  NaN
# ...

# %%
df = pd.DataFrame()

for city,lang in d_.items():
    tmp = pd.DataFrame(list(lang.items()))
    tmp['city'] = city
    df = df.append(tmp)
df.columns = ['lang','perc','city']
dfp = df.pivot(index='city',columns='lang',values='perc')

fig = plt.figure()
fig, ax = plt.subplots(1,1, figsize=(20,12))
heatplot = ax.imshow(dfp, cmap='BuGn')
ax.set_xticklabels(dfp.columns)
ax.set_yticklabels(dfp.index)

tick_spacing = 1.1
ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
ax.yaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))
#ax.set_title("Heatmap of Flight Density from 1949 to 1961")
#ax.set_xlabel('Year')
#ax.set_ylabel('Month')

# %%
df = dict()

for k,v in d_.items():
    for lan,sc in v.items():
        if lan in df.keys():
            df[lan] += sc
        else:
            df.update({lan:sc})
df = pd.DataFrame(list(df.items()))
df.columns = ['lang','perc']
df.index = df['lang']
df.plot.pie(x='lang',y='perc', figsize=(25, 25))

# %%
df
# Out:
#    lang      perc
# 0    es  0.222187
# 1    hr  0.043790
# 2    fr  0.139973
# 3    bs  0.002219
# 4    it  1.776501
# 5    en  0.869566
# 6    cy  0.071784
# 7    cs  0.007786
# 8    mt  0.002219
# 9    sk  0.018021
# 10   de  0.140442
# 11   el  0.108171
# 12   ko  0.008915
# 13   an  0.065537
# 14   tr  0.064484
# 15   ca  0.032850
# 16   zh  0.010005
# 17   pl  0.036583
# 18   da  0.038262
# 19   ht  0.040748
# 20   id  0.004438
# 21   nl  0.054340
# 22   br  0.029658
# 23   hu  0.006658
# 24   sq  0.021448
# 25   eo  0.029385
# 26   lt  0.002219
# 27   vo  0.003310
# 28   sw  0.002219
# 29   gl  0.008172
# 30   pt  0.021487
# 31   hi  0.002219
# 32   sl  0.028953
# 33   qu  0.011096
# 34   ru  0.008172
# 35   la  0.003348
# 36   et  0.001129
# 37   fa  0.017857
# 38   sv  0.011905
# 39   af  0.005952
# 40   ja  0.023810
# 41   fi  0.001091
# 42   ro  0.001091
