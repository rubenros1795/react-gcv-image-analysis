# %%
from functions import *
from random import sample
from htmldate import find_date
from concurrent.futures import ThreadPoolExecutor
from bs4 import BeautifulSoup
import json
from langid.langid import LanguageIdentifier, model
from collections import Counter
import matplotlib.pyplot as plt
import matplotlib
from tqdm import tqdm
import operator

# %%
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import random

# %%
model = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300-SLIM.bin',binary=True)
model.init_sims(replace=True)

# %%
with open('sentences-titles-en.txt','r') as f:
    sentences = f.readlines()

vocab = list(model.wv.vocab)

sentences = [s.replace('\n','').split(' ') for s in sentences]
sentences = [s for s in sentences if len(s) > 9]
sentences = [s for s in tqdm(sentences) if len([w for w in s if w in vocab]) > 9]
print('number of sentences: {}'.format(len(sentences)))
# Out:
# /home/ruben/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   after removing the cwd from sys.path.
# 100%|██████████| 8624/8624 [04:19<00:00, 33.30it/s]
# number of sentences: 2580

# %%
def document_vector(word2vec_model, doc):
    doc = [word for word in doc if word in model.wv.vocab]
    return np.mean(model[doc], axis=0)

# %%
sentences2 = []

for s in tqdm(sentences): # append the vector for each document
    sentences2.append(document_vector(model, s))
    
sentences2 = np.array(sentences2) # list to array
# Out:
#   0%|          | 0/2580 [00:00<?, ?it/s]/home/ruben/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#
# 100%|██████████| 2580/2580 [00:00<00:00, 12330.19it/s]

# %%
from sklearn.manifold import TSNE

# Initialize t-SNE
tsne = TSNE(n_components = 2, init = 'random', random_state = 10, perplexity = 100)

# Again use only 400 rows to shorten processing time
tsne_df = tsne.fit_transform(sentences2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from adjustText import adjust_text


fig, ax = plt.subplots(figsize = (14, 10))
sns.scatterplot(tsne_df[:, 0], tsne_df[:, 1], alpha = 0.5)

texts = []
titles_to_plot = list(np.arange(0, 400, 40)) # plots every 40th title in first 400 titles

# Append words to list
for title in titles_to_plot:
    texts.append(plt.text(tsne_df[title, 0], tsne_df[title, 1], titles_list[title], fontsize = 14))
    
# Plot text using adjust_text
adjust_text(texts, force_points = 0.4, force_text = 0.4, 
            expand_points = (2,1), expand_text = (1,2),
            arrowprops = dict(arrowstyle = "-", color = 'black', lw = 0.5))

plt.show()

# %%
# Load the library with the CountVectorizer method
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

count_vectorizer = CountVectorizer(stop_words='english')# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(sentences)# Visualise the 10 most common words
# Out:
# /home/ruben/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Load the LDA model from sk-learn
from sklearn.decomposition import LatentDirichletAllocation as LDA
 
# Helper function
def print_topics(model, count_vectorizer, n_top_words):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
        
# Tweak the two parameters below
number_topics = 10
number_words = 20 # Create and fit the LDA model
lda = LDA(n_components=number_topics, n_jobs=-1)
lda.fit(count_data)# Print the topics found by the LDA model
print_topics(lda, count_vectorizer, number_words)
# Out:
# Topics found via LDA:
#
# Topic #0:
# public art iran protest people years policy archives action killed institute soleimani strike cctv qassam drone studies useful 30 pete
#
# Topic #1:
# rachel corrie people death protest quora peace february young vic reviving fair doves lie page libels surrounding debunking israel activist
#
# Topic #2:
# war iraq wikipedia page protest antiwar peace stop 2003 coalition london protests blog future invasion youtube rock outernational world wikivisually
#
# Topic #3:
# iraq war history times remember ignored chilcot streets outernational blood world antiwar protesters financial raised fist inquiry marches report amplifier
#
# Topic #4:
# new vision clear topic view profile nationstates twitter facebook women amir amirani democratic westport cecil interview march larratt zentastic shannon
#
# Topic #5:
# iraq 2003 invasion calm airstrike baghdad markets shatters war february police told lives spies reader trump know jew solidarity day
#
# Topic #6:
# iran trump war won taunts ordering saying says tov boker strike boulder tweet missile rally tens thousands rachel crimes capital
#
# Topic #7:
# protests 15 february antiwar history 2003 march years protest film pictures 180 125 f15 israellycool page largest text crowd war
#
# Topic #8:
# images war global challenges photos fairey shepard amp selfdetermination responsibility stock iraq pictures royaltyfree military getty young best wiki fandom
#
# Topic #9:
# general iranian death america thousands funeral chant new soleimani advice dubai travel killed iran safe strike fist right lindsey graham
