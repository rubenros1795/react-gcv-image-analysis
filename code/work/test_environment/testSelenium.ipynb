# %%
from selenium import webdriver
import codecs
import article
driver = webdriver.Chrome(executable_path=r'C:/Users/Ruben/Documents/GitHub/ReACT_GCV/code/work/scrape_environment/chromedriver.exe')

# %%
driver.get('https://www.anandabazar.com/international/this-single-photograph-helped-to-stop-vietnam-war-dgtl-1.961109')

# %%
completeName = "test.html"
file_object = codecs.open(completeName, "w", "utf-8")
html = driver.page_source
file_object.write(html)

# %%
from newspaper import Article

# %%
a = Article('https://www.anandabazar.com/international/this-single-photograph-helped-to-stop-vietnam-war-dgtl-1.961109'তখন ‘নাপাম বোমা’ আর কুখ্যাত রাসায়নিক বিষ ‘এজেন্ট অরেঞ্জ’ ঢালছে মার্কিন সেনা। স্থানীয় কাওদাই মন্দির চত্বর ছেড়ে নিরাপদ আশ্রয়ের দিকে রওনা দিয়েছিল কিম ফুক ও তার গ্রামের লোকজন। বোমারু বিমান রেহাই দেয়নি তাঁদের। ওপর)

with open(completeName, 'rb') as fh:
    a.html = fh.read()
    a.download_state = 2
    a.parse()
    text = a.text

# %%
html
# Out:
# '<html lang="bn"><head><script type="text/javascript" async="" src="https://sb.scorecardresearch.com/c2/17824659/cs.js"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script src="https://www.googletagservices.com/activeview/js/current/osd.js?cb=%2Fr20100101"></script><script charset="UTF-8" type="text/javascript" async="async" src="https://cdn.taboola.com/libtrc/userx.20200223-4-RELEASE.es6.js"></script><script type="text/javascript" async="" src="https://rtbpassback.andbeyond.media/prebid-scortb-2.44.1.js"></script><script src="https://connect.facebook.net/en_US/sdk.js?hash=741f5a185748ad0a7898df21129c7185&amp;ua=modern_es6" async="" crossorigin="anonymous"></script><script src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_rendering_2020022001.js"></script><script type="text/javascript" src="https://m.addthis.com/live/red_lojson/300lo.json?si=5e5661aeee2ea21c&amp;bkl=0&amp;bl=1&amp;pdt=150&amp;sid=5e5661aeee2ea21c&amp;pub=ra-520287e126f06
# ...
