# %%
import os
import shutil
import glob
import math
import argparse
import warnings
import numpy as np
from PIL import Image
from tqdm import tqdm
from multiprocessing.dummy import Pool as ThreadPool
from multiprocessing import cpu_count

# %%
Image.MAX_IMAGE_PIXELS = None
warnings.simplefilter('ignore')

# %%
class K_means:

  def __init__(self, k=3, size=False, resample=32):
    self.k = k
    self.cluster = []
    self.data = []
    self.end = []
    self.i = 0
    self.size = size
    self.resample = resample

  def manhattan_distance(self,x1,x2):
    s = 0.0
    for i in range(len(x1)):
      s += abs( float(x1[i]) - float(x2[i]) )
    return s

  def euclidian_distance(self,x1,x2):
    s = 0.0
    for i in range(len(x1)):
      s += math.sqrt((float(x1[i]) - float(x2[i])) ** 2)
    return s

  def read_image(self,im):
    if self.i >= self.k :
      self.i = 0
    try:
      img = Image.open(im)
      osize = img.size
      img.thumbnail((self.resample,self.resample))
      v = [float(p)/float(img.size[0]*img.size[1])*100  for p in np.histogram(np.asarray(img))[0]]
      if self.size :
        v += [osize[0], osize[1]]
      pbar.update(1)
      i = self.i
      self.i += 1
      return [i, v, im]
    except Exception as e:
      print("Error reading ",im,e)
      return [None, None, None]


  def generate_k_means(self):
    final_mean = []
    for c in range(self.k):
      partial_mean = []
      for i in range(len(self.data[0])):
        s = 0.0
        t = 0
        for j in range(len(self.data)):
          if self.cluster[j] == c :
            s += self.data[j][i]
            t += 1
        if t != 0 :
          partial_mean.append(float(s)/float(t))
        else:
          partial_mean.append(float('inf'))
      final_mean.append(partial_mean)
    return final_mean

  def generate_k_clusters(self,folder):
    pool = ThreadPool(cpu_count())
    result = pool.map(self.read_image, folder)
    pool.close()
    pool.join()
    self.cluster = [r[0] for r in result if r[0] != None]
    self.data = [r[1] for r in result if r[1] != None]
    self.end = [r[2] for r in result if r[2] != None]

  def rearrange_clusters(self):
    isover = False
    while(not isover):
      isover = True
      m = self.generate_k_means()
      for x in range(len(self.cluster)):
        dist = []
        for a in range(self.k):
          dist.append( self.manhattan_distance(self.data[x],m[a]) )
        _mindist = dist.index(min(dist))
        if self.cluster[x] != _mindist :
          self.cluster[x] = _mindist
          isover = False

# %%
args = {"folder":"/media/ruben/Data Drive/test","kmeans":80,"resample":128,"size":False,"move":False}
types = ('*.jpg', '*.JPG', '*.png', '*.jpeg')
imagePaths = []
folder = args["folder"]
if not folder.endswith("/") :
    folder+="/"
for files in types :
    imagePaths.extend(sorted(glob.glob(folder+files)))
nimages = len(imagePaths)
nfolders = int(math.log(args["kmeans"], 10))+1
if nimages <= 0 :
    print("No images found!")
    #exit()
if args["resample"] < 16 or args["resample"] > 256 :
    print("-r should be a value between 16 and 256")
    #exit()
pbar = tqdm(total=nimages)
# Out:
#   0%|          | 0/622 [00:00<?, ?it/s]

# %%
k = K_means(args["kmeans"],args["size"],args["resample"])
k.generate_k_clusters(imagePaths)
k.rearrange_clusters()
# Out:
#   0%|          | 3/622 [00:00<04:44,  2.18it/s]
#
#
#   1%|▏         | 8/622 [00:00<02:29,  4.12it/s]
#
#
#   1%|▏         | 8/622 [00:00<02:29,  4.12it/s]
#
#
#   1%|▏         | 9/622 [00:00<02:28,  4.12it/s]
#
#
#   2%|▏         | 12/622 [00:00<02:28,  4.12it/s]
#
#
#   3%|▎         | 16/622 [00:00<02:27,  4.12it/s]
#
#
#   4%|▍         | 24/622 [00:00<01:44,  5.73it/s]
#
#
#   4%|▍         | 27/622 [00:00<00:54, 10.85it/s]
#
#
#   5%|▍         | 31/622 [00:00<00:54, 10.85it/s]
#
#
#   7%|▋         | 41/622 [00:00<00:23, 24.57it/s]
#
#
#   7%|▋         | 45/622 [00:00<00:12, 45.70it/s]
#
#
#   7%|▋         | 46/622 [00:00<00:12, 45.70it/s]
#
#
#   8%|▊         | 48/622 [00:00<00:12, 45.70it/s]
#
#
#   8%|▊         | 50/622 [00:00<00:12, 45.70it/s]
#
#
#   9%|▊         | 53/622 [00:01<00:12, 45.70it/s]
#
#
#  10%|█         | 64/622 [00:01<00:11, 47.18it/s]
#
#
#  11%|█▏        | 70/622 [00:01<00:11, 47.34it/s]
#
#
#  11%|█▏        | 71/622 [00:01<00:11, 47.34it/s]
#
#
#  13%|█▎        | 80/622 [00:01<00:09, 55.88it/s]
#
#
#  14%|█▍        | 86/622 [00:01<00:08, 60.20it/s]
#
#
#  14%|█▍        | 86/622 [00:01<00:08, 60.20it/s]
#
#
#  16%|█▌        | 100/622 [00:01<00:06, 76.79it/s]
#
#
#  16%|█▋        | 102/622 [00:01<00:05, 93.25it/s]
#
#
#  17%|█▋        | 106/622 [00:01<00:05, 93.25it/s]
#
#
#  17%|█▋        | 107/622 [00:01<00:05, 93.25it/s]
#
#
#  20%|█▉        | 123/622 [00:01<00:06, 77.09it/s]
#
#
#  20%|██        | 127/622 [00:01<00:05, 83.25it/s]
#
#
#  21%|██        | 128/622 [00:01<00:05, 83.25it/s]
#
#
#  21%|██        | 128/622 [00:01<00:05, 83.25it/s]
#
#
#  21%|██        | 128/622 [00:01<00:05, 83.25it/s]
#
#
#  21%|██▏       | 133/622 [00:01<00:05, 83.25it/s]
#
#
#  23%|██▎       | 145/622 [00:01<00:05, 86.90it/s]
#
#
#  24%|██▍       | 149/622 [00:01<00:04, 106.90it/s]
#
#
#  24%|██▍       | 150/622 [00:01<00:04, 106.90it/s]
#
#
#  24%|██▍       | 150/622 [00:01<00:04, 106.90it/s]
#
#
#  25%|██▍       | 153/622 [00:01<00:04, 106.90it/s]
#
#
#  25%|██▍       | 154/622 [00:01<00:04, 106.90it/s]
#
#
#  25%|██▌       | 158/622 [00:01<00:04, 106.90it/s]
#
#
#  28%|██▊       | 172/622 [00:01<00:05, 83.70it/s]
#
#
#  28%|██▊       | 175/622 [00:01<00:05, 82.83it/s]
#
#
#  28%|██▊       | 176/622 [00:01<00:05, 82.83it/s]
#
#
#  29%|██▉       | 180/622 [00:01<00:05, 82.83it/s]
#
#
#  29%|██▉       | 183/622 [00:01<00:05, 82.83it/s]
#
#
#  31%|███▏      | 195/622 [00:01<00:05, 82.33it/s]
#
#
#  38%|███▊      | 237/622 [00:02<00:01, 205.71it/s]
#
#
#  38%|███▊      | 239/622 [00:02<00:01, 205.71it/s]
#
#
#  39%|███▊      | 240/622 [00:02<00:01, 205.71it/s]
#
#
#  39%|███▉      | 242/622 [00:02<00:01, 205.71it/s]
#
#
#  45%|████▍     | 277/622 [00:02<00:01, 223.35it/s]
#
#
#  45%|████▌     | 282/622 [00:02<00:01, 255.41it/s]
#
#
#  45%|████▌     | 282/622 [00:02<00:01, 255.41it/s]
#
#
#  46%|████▌     | 284/622 [00:02<00:01, 255.41it/s]
#
#
#  46%|████▌     | 285/622 [00:02<00:01, 255.41it/s]
#
#
#  46%|████▌     | 285/622 [00:02<00:01, 255.41it/s]
#
#
#  46%|████▋     | 289/622 [00:02<00:01, 255.41it/s]
#
#
#  51%|█████     | 318/622 [00:02<00:01, 234.00it/s]
#
#
#  52%|█████▏    | 323/622 [00:02<00:01, 211.86it/s]
#
#
#  52%|█████▏    | 325/622 [00:02<00:01, 211.86it/s]
#
#
#  52%|█████▏    | 326/622 [00:02<00:01, 211.86it/s]
#
#
#  57%|█████▋    | 354/622 [00:02<00:01, 196.20it/s]
#
#
#  57%|█████▋    | 354/622 [00:02<00:01, 196.20it/s]
#
#
#  57%|█████▋    | 357/622 [00:02<00:01, 196.20it/s]
#
#
#  63%|██████▎   | 389/622 [00:02<00:01, 218.67it/s]
#
#
#  64%|██████▎   | 395/622 [00:02<00:00, 270.17it/s]
#
#
#  64%|██████▎   | 396/622 [00:02<00:00, 270.17it/s]
#
#
#  64%|██████▍   | 398/622 [00:02<00:00, 270.17it/s]
#
#
#  70%|██████▉   | 434/622 [00:02<00:00, 293.06it/s]
#
#
#  70%|███████   | 436/622 [00:02<00:00, 305.89it/s]
#
#
#  71%|███████   | 439/622 [00:02<00:00, 305.89it/s]
#
#
#  71%|███████   | 439/622 [00:02<00:00, 305.89it/s]
#
#
#  76%|███████▋  | 475/622 [00:02<00:00, 312.90it/s]
#
#
#  77%|███████▋  | 479/622 [00:02<00:00, 328.39it/s]
#
#
#  77%|███████▋  | 482/622 [00:02<00:00, 328.39it/s]
#
#
#  78%|███████▊  | 483/622 [00:02<00:00, 328.39it/s]
#
#
#  84%|████████▍ | 522/622 [00:02<00:00, 256.79it/s]
#
#
#  84%|████████▍ | 524/622 [00:02<00:00, 232.37it/s]
#
#
#  85%|████████▍ | 528/622 [00:02<00:00, 232.37it/s]
#
#
#  85%|████████▍ | 528/622 [00:02<00:00, 232.37it/s]
#
#
#  89%|████████▉ | 556/622 [00:03<00:00, 218.78it/s]
#
#
#  90%|█████████ | 560/622 [00:03<00:00, 207.04it/s]
#
#
#  90%|█████████ | 562/622 [00:03<00:00, 207.04it/s]
#
#
#  91%|█████████ | 563/622 [00:03<00:00, 207.04it/s]
#
#
#  95%|█████████▍| 588/622 [00:03<00:00, 186.51it/s]
#
#
#  98%|█████████▊| 608/622 [00:03<00:00, 189.35it/s]
#
#
#  98%|█████████▊| 611/622 [00:03<00:00, 204.61it/s]
#
#
#  99%|█████████▊| 614/622 [00:03<00:00, 204.61it/s]
#
#
#  99%|█████████▉| 615/622 [00:03<00:00, 204.61it/s]
#
#
# 100%|██████████| 622/622 [00:16<00:00, 204.61it/s]

# %%
for i in range(50):
    print(k.end[i],k.cluster[i])
# Out:
# /media/ruben/Data Drive/test/00a52ce4-aa38-11ea-a49c-b0359fc72c2e.jpg 42
# /media/ruben/Data Drive/test/00b16690-aa39-11ea-a6d7-b0359fc72c2e.jpg 53
# /media/ruben/Data Drive/test/00b6930a-aa39-11ea-bae2-b0359fc72c2e.jpg 39
# /media/ruben/Data Drive/test/00bb988b-aa39-11ea-a9c1-b0359fc72c2e.jpg 66
# /media/ruben/Data Drive/test/00c973f6-aa39-11ea-924f-b0359fc72c2e.jpg 54
# /media/ruben/Data Drive/test/00d8162c-aa38-11ea-9e61-b0359fc72c2e.jpg 45
# /media/ruben/Data Drive/test/00dc9f06-aa39-11ea-a97d-b0359fc72c2e.jpg 27
# /media/ruben/Data Drive/test/00de4b8c-aa39-11ea-bb3d-b0359fc72c2e.jpg 39
# /media/ruben/Data Drive/test/00dea13a-aa38-11ea-b3a8-b0359fc72c2e.jpg 33
# /media/ruben/Data Drive/test/00e30c00-aa38-11ea-b571-b0359fc72c2e.jpg 34
# /media/ruben/Data Drive/test/00e4b62e-aa39-11ea-80af-b0359fc72c2e.jpg 15
# /media/ruben/Data Drive/test/00f882ca-aa39-11ea-a7a4-b0359fc72c2e.jpg 74
# /media/ruben/Data Drive/test/00f90e54-aa38-11ea-9691-b0359fc72c2e.jpg 25
# /media/ruben/Data Drive/test/00f994af-aa39-11ea-a994-b0359fc72c2e.jpg 54
# /media/ruben/Data Drive/test/00fd7f29-aa38-11ea-86fc-b0359fc72c2e.jpg 55
# /media/ruben/Data Drive/test/01ae7582-aa39-11ea-91d2-b0359fc72c2e.jpg 2
# /media/ruben/Data Drive/test/01b2b6ef-aa39-11ea-a20f-b0359fc72c2e.jpg 48
# /media/ruben/Data Drive/test/01b747c0-aa39-11ea-ab08-b0359fc72c2e.jpg 65
# /media/ruben/Data Drive/test/01bb635f-aa39-11ea-b33b-b0359fc72c2e.jpg 5
# /media/ruben/Data Drive/test/01bbd835-aa39-11ea-aa58-b0359fc72c2e.jpg 7
# /media/ruben/Data Drive/test/01c83ff1-aa38-11ea-ac39-b0359fc72c2e.jpg 19
# /media/ruben/Data Drive/test/01d6f742-aa39-11ea-9d0b-b0359fc72c2e.jpg 63
# /media/ruben/Data Drive/test/01d966f6-aa39-11ea-8cba-b0359fc72c2e.jpg 52
# /media/ruben/Data Drive/test/01dc13d2-aa39-11ea-8211-b0359fc72c2e.jpg 39
# /media/ruben/Data Drive/test/01dc9f2e-aa38-11ea-88d8-b0359fc72c2e.jpg 36
# /media/ruben/Data Drive/test/01dd3afe-aa38-11ea-a9c4-b0359fc72c2e.jpg 61
# /media/ruben/Data Drive/test/01e16cb6-aa38-11ea-bf19-b0359fc72c2e.jpg 52
# /media/ruben/Data Drive/test/01eb18a6-aa38-11ea-9d8d-b0359fc72c2e.jpg 17
# /media/ruben/Data Drive/test/01f2189c-aa38-11ea-b350-b0359fc72c2e.jpg 46
# /media/ruben/Data Drive/test/01ff0892-aa38-11ea-a5ff-b0359fc72c2e.jpg 61
# /media/ruben/Data Drive/test/02a6b7ba-aa39-11ea-8ed0-b0359fc72c2e.jpg 21
# /media/ruben/Data Drive/test/02a7c914-aa38-11ea-8ccb-b0359fc72c2e.jpg 59
# /media/ruben/Data Drive/test/02a815bb-aa39-11ea-8f3c-b0359fc72c2e.jpg 21
# /media/ruben/Data Drive/test/02a8ff7e-aa39-11ea-8c81-b0359fc72c2e.jpg 6
# /media/ruben/Data Drive/test/02acf466-aa39-11ea-9a6c-b0359fc72c2e.jpg 74
# /media/ruben/Data Drive/test/02c87fe8-aa39-11ea-b133-b0359fc72c2e.jpg 61
# /media/ruben/Data Drive/test/02cda92e-aa38-11ea-800c-b0359fc72c2e.jpg 44
# /media/ruben/Data Drive/test/02d5af1a-aa39-11ea-a74f-b0359fc72c2e.jpg 46
# /media/ruben/Data Drive/test/02db9df0-aa39-11ea-bf3d-b0359fc72c2e.jpg 36
# /media/ruben/Data Drive/test/02e13f68-aa39-11ea-8dff-b0359fc72c2e.jpg 15
# /media/ruben/Data Drive/test/02e639ca-aa38-11ea-a12d-b0359fc72c2e.jpg 1
# /media/ruben/Data Drive/test/02f84936-aa39-11ea-8dbd-b0359fc72c2e.jpg 68
# /media/ruben/Data Drive/test/03b61918-aa39-11ea-9059-b0359fc72c2e.jpg 19
# /media/ruben/Data Drive/test/03b63aca-aa38-11ea-b86c-b0359fc72c2e.jpg 36
# /media/ruben/Data Drive/test/03b80e52-aa38-11ea-8318-b0359fc72c2e.jpg 61
# /media/ruben/Data Drive/test/0a03b135-aa39-11ea-89e8-b0359fc72c2e.jpg 39
# /media/ruben/Data Drive/test/0a08c59c-aa38-11ea-8dc4-b0359fc72c2e.jpg 66
# /media/ruben/Data Drive/test/0a0a7246-aa38-11ea-bccd-b0359fc72c2e.jpg 47
# /media/ruben/Data Drive/test/0a19e8d9-aa39-11ea-9c7a-b0359fc72c2e.jpg 13
# /media/ruben/Data Drive/test/0a250bca-aa38-11ea-9d78-b0359fc72c2e.jpg 55

# %%
for i in range(k.k) :
	try :
	  os.makedirs(folder+str(i+1).zfill(nfolders))
	except :
	  print("Folder already exists")
action = shutil.copy
if args["move"] :
	action = shutil.move
for i in range(len(k.cluster)):
	action(k.end[i], folder+"/"+str(k.cluster[i]+1).zfill(nfolders)+"/")
